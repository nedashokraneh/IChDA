# %%
import sys
sys.path.append("../../Hi-C-embedding/GraphEmbedding")
import pandas as pd
import numpy as np
from ge import LINE
import networkx as nx
from ge.classify import read_node_label
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
def plot_embeddings(embeddings,):
    X, Y = read_node_label('../../Hi-C-embedding/GraphEmbedding/data/wiki/wiki_labels.txt')
    print(len(X))
    print(len(Y))
    emb_list = []
    color_idx = {}
    
    for idx,(k,c) in enumerate(zip(X,Y)):
        if int(k) in embeddings:
            emb_list.append(embeddings[int(k)])
            color_idx.setdefault(c[0], [])
            color_idx[c[0]].append(idx)
    print(idx)  
    emb_list = np.array(emb_list)

    model = TSNE(n_components=2)
    node_pos = model.fit_transform(emb_list)

    

    for c, idx in color_idx.items():
        plt.scatter(node_pos[idx, 0], node_pos[idx, 1], label=c)
    plt.legend()
    plt.show()

# %%
wiki_edge_list = pd.read_csv("../../Hi-C-embedding/GraphEmbedding/data/wiki/Wiki_edgelist.txt", sep = " ", header = None)
wiki_edge_list.columns = ['source','target']
wiki_edge_list.sort_values(by=['source','target'], inplace = True)
uni_dir_wiki_edge_list = wiki_edge_list[wiki_edge_list['source']<=wiki_edge_list['target']]

uni_G = nx.from_pandas_edgelist(uni_dir_wiki_edge_list, 'source', 'target', create_using=nx.DiGraph())
bi_G = nx.from_pandas_edgelist(wiki_edge_list, 'source', 'target', create_using=nx.DiGraph())

# %%
model = LINE(uni_G, embedding_size=128, order='second')
model.train(batch_size=1024, epochs=50, verbose=2)
uni_embeddings = model.get_embeddings()

model = LINE(bi_G, embedding_size=128, order='second')
model.train(batch_size=1024, epochs=50, verbose=2)
bi_embeddings = model.get_embeddings()
# Out:
# Epoch 1/50
# 0s - loss: 24.9007
# Epoch 2/50
# 0s - loss: 23.0663
# Epoch 3/50
# 0s - loss: 20.8599
# Epoch 4/50
# 0s - loss: 18.8576
# Epoch 5/50
# 0s - loss: 16.9629
# Epoch 6/50
# 0s - loss: 15.3708
# Epoch 7/50
# 0s - loss: 13.4913
# Epoch 8/50
# 0s - loss: 12.4852
# Epoch 9/50
# 0s - loss: 11.1901
# Epoch 10/50
# 0s - loss: 10.0446
# Epoch 11/50
# 0s - loss: 9.0046
# Epoch 12/50
# 0s - loss: 8.0055
# Epoch 13/50
# 0s - loss: 6.9471
# Epoch 14/50
# 0s - loss: 6.3851
# Epoch 15/50
# 0s - loss: 5.6901
# Epoch 16/50
# 0s - loss: 5.0736
# Epoch 17/50
# 0s - loss: 4.5048
# Epoch 18/50
# 0s - loss: 4.1295
# Epoch 19/50
# 0s - loss: 3.5944
# Epoch 20/50
# 0s - loss: 3.2761
# Epoch 21/50
# 0s - loss: 2.9958
# Epoch 22/50
# 0s - loss: 2.7363
# Epoch 23/50
# 0s - loss: 2.5191
# Epoch 24/50
# 0s - loss: 2.3257
# Epoch 25/50
# 0s - loss: 2.1209
# Epoch 26/50
# 0s - loss: 1.9551
# Epoch 27/50
# 0s - loss: 1.8778
# Epoch 28/50
# 0s - loss: 1.7642
# Epoch 29/50
# 0s - loss: 1.6124
# Epoch 30/50
# 0s - loss: 1.5311
# Epoch 31/50
# 0s - loss: 1.4514
# Epoch 32/50
# 0s - loss: 1.4100
# Epoch 33/50
# 0s - loss: 1.3371
# Epoch 34/50
# 0s - loss: 1.2781
# Epoch 35/50
# 0s - loss: 1.2281
# Epoch 36/50
# 0s - loss: 1.1701
# Epoch 37/50
# 0s - loss: 1.1297
# Epoch 38/50
# 0s - loss: 1.0895
# Epoch 39/50
# 0s - loss: 1.0485
# Epoch 40/50
# 0s - loss: 1.0231
# Epoch 41/50
# 0s - loss: 0.9710
# Epoch 42/50
# 0s - loss: 0.9466
# Epoch 43/50
# 0s - loss: 0.9186
# Epoch 44/50
# 0s - loss: 0.9005
# Epoch 45/50
# 0s - loss: 0.8853
# Epoch 46/50
# 0s - loss: 0.8644
# Epoch 47/50
# 0s - loss: 0.8327
# Epoch 48/50
# 0s - loss: 0.8172
# Epoch 49/50
# 0s - loss: 0.7976
# Epoch 50/50
# 0s - loss: 0.8064
# Epoch 1/50
# 0s - loss: 24.1218
# Epoch 2/50
# 0s - loss: 20.0879
# Epoch 3/50
# 0s - loss: 16.4304
# Epoch 4/50
# 0s - loss: 13.3818
# Epoch 5/50
# 0s - loss: 10.7977
# Epoch 6/50
# 0s - loss: 8.6771
# Epoch 7/50
# 0s - loss: 6.8936
# Epoch 8/50
# 0s - loss: 5.5273
# Epoch 9/50
# 0s - loss: 4.4004
# Epoch 10/50
# 0s - loss: 3.5723
# Epoch 11/50
# 0s - loss: 2.9343
# Epoch 12/50
# 0s - loss: 2.4396
# Epoch 13/50
# 0s - loss: 2.0760
# Epoch 14/50
# 0s - loss: 1.7982
# Epoch 15/50
# 0s - loss: 1.5935
# Epoch 16/50
# 0s - loss: 1.4361
# Epoch 17/50
# 0s - loss: 1.2914
# Epoch 18/50
# 0s - loss: 1.1986
# Epoch 19/50
# 0s - loss: 1.0967
# Epoch 20/50
# 0s - loss: 1.0329
# Epoch 21/50
# 0s - loss: 0.9806
# Epoch 22/50
# 0s - loss: 0.9325
# Epoch 23/50
# 0s - loss: 0.8820
# Epoch 24/50
# 0s - loss: 0.8542
# Epoch 25/50
# 0s - loss: 0.8217
# Epoch 26/50
# 0s - loss: 0.7970
# Epoch 27/50
# 0s - loss: 0.7642
# Epoch 28/50
# 0s - loss: 0.7434
# Epoch 29/50
# 0s - loss: 0.7186
# Epoch 30/50
# 0s - loss: 0.6985
# Epoch 31/50
# 0s - loss: 0.6715
# Epoch 32/50
# 0s - loss: 0.6502
# Epoch 33/50
# 0s - loss: 0.6251
# Epoch 34/50
# 0s - loss: 0.6007
# Epoch 35/50
# 0s - loss: 0.5719
# Epoch 36/50
# 0s - loss: 0.5499
# Epoch 37/50
# 0s - loss: 0.5278
# Epoch 38/50
# 0s - loss: 0.5012
# Epoch 39/50
# 0s - loss: 0.4730
# Epoch 40/50
# 0s - loss: 0.4507
# Epoch 41/50
# 0s - loss: 0.4292
# Epoch 42/50
# 0s - loss: 0.4078
# Epoch 43/50
# 0s - loss: 0.3845
# Epoch 44/50
# 0s - loss: 0.3645
# Epoch 45/50
# 0s - loss: 0.3482
# Epoch 46/50
# 0s - loss: 0.3278
# Epoch 47/50
# 0s - loss: 0.3087
# Epoch 48/50
# 0s - loss: 0.2954
# Epoch 49/50
# 0s - loss: 0.2837
# Epoch 50/50
# 0s - loss: 0.2667

# %%
len(uni_embeddings)
# Out:
# 2230

# %%
plot_embeddings(uni_embeddings)
# Out:
# 2405
# 2405
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-43-64b9e9fbf9e5> in <module>
# ----> 1 plot_embeddings(uni_embeddings)
#
# <ipython-input-42-73b4936f9050> in plot_embeddings(embeddings)
#      20
#      21     for c, idx in color_idx.items():
# ---> 22         plt.scatter(node_pos[idx, 0], node_pos[idx, 1], label=c)
#      23     plt.legend()
#      24     plt.show()
#
# IndexError: index 2390 is out of bounds for axis 0 with size 2230
