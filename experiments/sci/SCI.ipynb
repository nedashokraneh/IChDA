# %%
import os
import sys
sys.path.append('../../alternatives/sci-master/sci')
import utils
sys.path.append("../../src/")
sys.path.append("../../utilities/")
import dataset_class
from dataset_class import dataset
import data_utils
import evaluation_utils
# Out:
#   File "../../src/dataset_class.py", line 248
#     chr1, fragmentMid1, chr2, fragmentMid2, _, pvalue, *_ = line.decode('UTF-8').split("\t")
#                                                        ^
# SyntaxError: invalid syntax

# %%
# !conda list
# Out:
# # packages in environment at /home/nedooshki/miniconda3:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                  2_kmp_llvm    conda-forge
# abseil-cpp                20211102.0           h27087fc_1    conda-forge
# absl-py                   1.1.0              pyhd8ed1ab_0    conda-forge
# aiohttp                   3.8.1            py37h540881e_1    conda-forge
# aiosignal                 1.2.0              pyhd8ed1ab_0    conda-forge
# alabaster                 0.7.12                     py_0    conda-forge
# anndata                   0.8.0              pyhd8ed1ab_1    conda-forge
# anyio                     3.6.1            py37h89c1867_0    conda-forge
# argon2-cffi               21.3.0             pyhd8ed1ab_0    conda-forge
# argon2-cffi-bindings      21.2.0           py37h540881e_2    conda-forge
# ...

# %%
GM12878_signals_names = ['DNase', 'H3K4me2', 'H3K27ac', 'H2A.Z', 'H3K9me3', 'H3K4me1', 'H3K27me3', 'H3K9ac', 'H3K4me3', 'H3K36me3', 'H3K79me2', 'H4K20me1']
GM12878_dataset = dataset('GM12878', 'hg19', 100000, '../../data/GM12878/hg19/Hi-C/GSE63525_GM12878_insitu_primary_30.hic',
                 '../../utilities/juicer_tools_1.22.01.jar', '../../data/GM12878/hg19/Hi-C/res100000',
                 GM12878_signals_names, '../../data/GM12878/hg19/genomic-assays/bin_100000/', 
                  '../../data/GM12878/hg19/res100000_datasets/',
                  '../../data/', '../../utilities/config.json')
GM12878_dataset.load_pos2ind_and_ind2pos_maps('../../data/valid_bins/hg19/GM12878_100000_bins.txt')
#GM12878_dataset.generate_sci_graph()

# %%
graphFile = '../../data/GM12878/hg19/res100000_datasets/interactions/sci_graph.txt'
embedding_files = run_LINE(graphFile, 25, 2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5778/2551575233.py in <module>
#       1 graphFile = '../../data/GM12878/hg19/res100000_datasets/interactions/sci_graph.txt'
# ----> 2 embedding_files = run_LINE(graphFile, 25, 2)
#
# NameError: name 'run_LINE' is not defined
