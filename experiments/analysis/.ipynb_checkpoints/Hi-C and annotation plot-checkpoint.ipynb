# %%
import sys
sys.path.append("../../src/")
sys.path.append("../../utilities/")
import dataset_class
from dataset_class import dataset
import data_utils
import evaluation_utils
from importlib import reload
dataset_class = reload(dataset_class)
from dataset_class import dataset

# %%
'''
signals_names = ['TSA-SON', 'TSA-LaminB', 'DamID-LaminB', 'DamID-Nucleolus']
dataset = dataset('K562', 'hg19', 25000, '../../../data/K562/hg38/Hi-C/4DNFITUOMFUQ.hic',
                 '../../../utilities/juicer_tools_1.22.01.jar', '../../../data/K562/hg38/Hi-C/res25000',
                 signals_names, '../../../data/K562/hg38/genomic-assays/', 
                  '../../../data/K562/hg38/res25000_datasets/',
                  '../../../data/', '../../../utilities/config.json')
dataset.load_pos2ind_and_ind2pos_maps('../../../data/valid_bins/hg38/K562_25000_bins.txt')
'''

# %%
GM12878_signals_names = ['DNase', 'H3K4me2', 'H3K27ac', 'H2A.Z', 'H3K9me3', 'H3K4me1', 'H3K27me3', 'H3K9ac', 'H3K4me3', 'H3K36me3', 'H3K79me2', 'H4K20me1']
K562_signals_names = ['DNase', 'H3K4me2', 'H3K27ac', 'H2A.Z', 'H3K9me3', 'H3K4me1', 'H3K27me3', 'H3K9ac', 'H3K4me3', 'H3K36me3', 'H3K79me2', 'H4K20me1', 'H3K9me1', 'LaminA_TSA-seq', 'SON_TSA-seq']

# %%
dataset = dataset('GM12878', 'hg19', 100000, '../../data/GM12878/hg19/Hi-C/GSE63525_GM12878_insitu_primary_30.hic',
                 '../../utilities/juicer_tools_1.22.01.jar', '../../data/GM12878/hg19/Hi-C/res100000',
                 GM12878_signals_names, '../../data/GM12878/hg19/genomic-assays/bin_100000/', 
                  '../../data/GM12878/hg19/res100000_datasets/',
                  '../../data/', '../../utilities/config.json')
dataset.load_pos2ind_and_ind2pos_maps('../../data/valid_bins/hg19/GM12878_100000_bins.txt')

# %%
chr21_signals = dataset.get_chrom_signals(21)
chr21_valid_bins = dataset.get_valid_bins(21)
chr21_mat = dataset.get_hic_mat(21,21,'oe')
chr21_mat = chr21_mat.toarray()[np.ix_(chr21_valid_bins,chr21_valid_bins)]

# %%
evaluation_utils.spatial_correlation(chr21_signals.iloc[:,0].values, chr21_mat)
# Out:
# {'moran': 0.20136184429535442, 'z_score': 80.18196679780365, 'p_value': 0.0}

# %%
chr21_valid_bins
# Out:
# /home/nedooshki/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# <AxesSubplot:>

# %%
evaluation_utils.spatial_correlation(chr1_signals.iloc[:,0].values, mat)
# Out:
# {'moran': 0.998767567063543, 'z_score': 95.23632852444031, 'p_value': 0.0}
